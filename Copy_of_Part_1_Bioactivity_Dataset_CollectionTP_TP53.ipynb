# %% [markdown]
# <a href="https://colab.research.google.com/github/ribka-5/Bioinformatika/blob/main/Copy_of_Part_1_Bioactivity_Dataset_CollectionTP_TP53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('TP53')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references      organism  \
# 0                                                  []  Homo sapiens
# 1                                                  []  Homo sapiens
# 2                                                  []  Mus musculus
# 3                                                  []  Homo sapiens
# 4   [{'xref_id': 'P02340', 'xref_name': None, 'xre...  Mus musculus
# 5   [{'xref_id': 'P04637', 'xref_name': None, 'xre...  Homo sapiens
# 6                                                  []  Homo sapiens
# 7                                                  []  Homo sapiens
# 8                                                  []  Homo sapiens
# 9                                                  []  Homo sapiens
# 10                                                 []  Homo sapiens
# 11                                                 []  Homo sapiens
# 12                                                 []  Homo sapiens
# ...

# %%
targets = [target for target in target_query if target.get('organism') == 'Homo sapiens']

targets = pd.DataFrame.from_dict(targets)
targets
# Out:
#                                      cross_references      organism  \
# 0                                                  []  Homo sapiens
# 1                                                  []  Homo sapiens
# 2                                                  []  Homo sapiens
# 3   [{'xref_id': 'P04637', 'xref_name': None, 'xre...  Homo sapiens
# 4                                                  []  Homo sapiens
# 5                                                  []  Homo sapiens
# 6                                                  []  Homo sapiens
# 7                                                  []  Homo sapiens
# 8                                                  []  Homo sapiens
# 9                                                  []  Homo sapiens
# 10                                                 []  Homo sapiens
# 11                                                 []  Homo sapiens
# 12                                                 []  Homo sapiens
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[7]
selected_target
# Out:
# 'CHEMBL1907611'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1616  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1617  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1618  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1619  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1620  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('TP53_01_bioactivity_data_raw_REAL.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1616  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1617  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1618  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1619  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1620  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1325

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1613  {'action_type': 'DISRUPTING AGENT', 'descripti...             None
# 1615  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1617  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1618  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1620  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL179549  CCCN1C(=O)c2ccccc2C1(NC(=O)c1ccc(C(C)(C)C)cc1)...
# 1          CHEMBL360920  CCCN1C(=O)c2ccccc2C1(NC(=O)c1ccccc1)c1ccc(C(C)...
# 2          CHEMBL182052  CCCOC1(c2ccccc2)c2ccccc2C(=O)N1C(Cc1ccc(O)cc1)...
# 3          CHEMBL179662  OCC(NC1(c2ccccc2)c2ccccc2CC1Cc1ccccc1)C(O)c1cc...
# 4          CHEMBL181688  CC(C)(C)c1ccc(COC2(c3ccccc3)c3ccccc3C(=O)N2Cc2...
# ...                 ...                                                ...
# 1613      CHEMBL5179820  CCC[C@H]1N(C(=O)c2c(C(F)(F)F)ccnc2O)CCC[C@@]1(...
# 1615      CHEMBL4169540  N=C(N)Nc1cccc(C(=O)NCC(=O)N[C@@H](CC(=O)O)C(=O...
# 1617      CHEMBL2313487  COc1cc(Cc2c(-c3ccn(S(=O)(=O)c4ccccc4)c3)[nH]c3...
# 1618      CHEMBL4095983  O=C(CC(c1ccccc1)c1ccccc1)N[C@@H](Cc1ccc(OCCCNc...
# 1620      CHEMBL3220312  Cc1c(Cl)ccc2c(/C=C3\NC(=O)N(C(C(=O)NC(CO)CO)c4...
#
#      standard_value
# 0           27000.0
# 1           66000.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('TP53_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('TP53_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL179549  CCCN1C(=O)c2ccccc2C1(NC(=O)c1ccc(C(C)(C)C)cc1)...
# 1          CHEMBL360920  CCCN1C(=O)c2ccccc2C1(NC(=O)c1ccccc1)c1ccc(C(C)...
# 2          CHEMBL182052  CCCOC1(c2ccccc2)c2ccccc2C(=O)N1C(Cc1ccc(O)cc1)...
# 3          CHEMBL179662  OCC(NC1(c2ccccc2)c2ccccc2CC1Cc1ccccc1)C(O)c1cc...
# 4          CHEMBL181688  CC(C)(C)c1ccc(COC2(c3ccccc3)c3ccccc3C(=O)N2Cc2...
# ...                 ...                                                ...
# 1320      CHEMBL5179820  CCC[C@H]1N(C(=O)c2c(C(F)(F)F)ccnc2O)CCC[C@@]1(...
# 1321      CHEMBL4169540  N=C(N)Nc1cccc(C(=O)NCC(=O)N[C@@H](CC(=O)O)C(=O...
# 1322      CHEMBL2313487  COc1cc(Cc2c(-c3ccn(S(=O)(=O)c4ccccc4)c3)[nH]c3...
# 1323      CHEMBL4095983  O=C(CC(c1ccccc1)c1ccccc1)N[C@@H](Cc1ccc(OCCCNc...
# 1324      CHEMBL3220312  Cc1c(Cl)ccc2c(/C=C3\NC(=O)N(C(C(=O)NC(CO)CO)c4...
#
#       standard_value     class
# 0           27000.00  inactive
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('TP53_03_bioactivity_data_curated.csv', index=False)

# %%
! zip TP53.zip *.csv
# Out:
#   adding: TP53_01_bioactivity_data_raw_REAL.csv (deflated 96%)
#   adding: TP53_02_bioactivity_data_preprocessed.csv (deflated 86%)
#   adding: TP53_03_bioactivity_data_curated.csv (deflated 87%)

# %%
! ls -l
# Out:
# total 2380
# drwxr-xr-x 1 root root    4096 Nov  9 14:25 sample_data
# -rw-r--r-- 1 root root 2030599 Nov 13 11:26 TP53_01_bioactivity_data_raw_REAL.csv
# -rw-r--r-- 1 root root  129472 Nov 13 11:27 TP53_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  140093 Nov 13 11:27 TP53_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  125557 Nov 13 11:27 TP53.zip

# %% [markdown]
# ---
